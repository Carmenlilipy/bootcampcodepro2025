# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
nombre = "carmen"
print(nombre)
apellido = "Quinonez"
print(apellido)
# Out:
# carmen
# Quinonez

# %%
frutas = "manzanas"
print(frutas)
cantidad = 5
print(cantidad)
# Out:
# manzanas
# 5

# %%
numeros = 12345
print(numeros)
# Out:
# 12345

# %%
#precio
precio_total = 19000
cantidad_gaseosa = 4
cantidad_personas = 15
precio_final = precio_total * cantidad_gaseosa
print(precio_final)
promedio_por_persona = precio_final / cantidad_personas
print(promedio_por_persona)
# Out:
# 76000
# 5066.666666666667

# %% [markdown]
# ## Challenge 🤺 - 20m
#
# Suma: asignar dos números en dos variables diferentes `cantidad_de_manzanas` y `cantidad_de_naranjas`. Luego sumar ambas variables en `cantidad_de_frutas`. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable `frutas_vendidas`. Luego, asignar la resta entre `cantidad_de_frutas` y `frutas_vendidas` a la variable `frutas_restantes`. Imprimir la última variable.

# %%
cantidad_manzanas = 4
cantidad_naranjas = 8
cantidad_frutas = cantidad_manzanas + cantidad_naranjas 
print(cantidad_frutas)
frutas_vendidas = 6
frutas_restantes = cantidad_frutas - frutas_vendidas
print(frutas_restantes)
# Out:
# 12
# 6

# %% [markdown]
# ## Challenge 🤺 - 15m
#
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
nombre = "Jorge" 
apellido = "Ruiz" 
print(f"Hola, me llamo {nombre} {apellido}, mucho gusto.")
# Out:
# Hola, me llamo Jorge Ruiz, mucho gusto.

# %%
numero1 = int(input("dame un numero"))
numero2 = int(input('dame otro numero'))
suma =

# %% [markdown]
# ### Challenge 🤺 - 10m
#
# Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

# %%
numero1 = int(input("dame un numero"))
numero2 = int(input('dame otro numero'))
suma = numero1+numero2
# suma 15+6 
print(suma)
# la suma de mis dos numeros es 21
# Out:
# 21

# %%
def preparar_sandwich():
    print('abrir el pan')
    print('agregar mayonesa')
    print('agregar tomate')
    print('agregar huevo')
    print('cerrar pan')
    print('listo!')

preparar_sandwich()
# Out:
# abrir el pan
# agregar mayonesa
# agregar tomate
# agregar huevo
# cerrar pan
# listo!

# %% [markdown]
# ## Challenge 🤺 - 10m
#
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
# Ejecutar la función 3 veces.

# %%
def tetraedro_del_fuego():
    print('combustible')
    print('calor')
    print('oxigeno')
    print('fuegoooooooo!!!')
    print(' ')
      
tetraedro_del_fuego()
tetraedro_del_fuego()
tetraedro_del_fuego()
# Out:
# combustible
# calor
# oxigeno
# fuegoooooooo!!!
#
# combustible
# calor
# oxigeno
# fuegoooooooo!!!
#
# combustible
# calor
# oxigeno
# fuegoooooooo!!!

# %% [markdown]
# ## Challenge 🤺 - 15m
#
# Escribir una funcion que nos pregunte las caracteriticas de un elemento a comprar e imprima el elemento con sus caracteristicas.

# %%
def preparar_sandwich(ingredientes):
    print('abrir el pan')
    print('agregar mayonesa')
    print(f'agregar {ingredientes}')
    print('cerrar pan')
    print('listo!')

preparar_sandwich('jamon')
# Out:
# abrir el pan
# agregar mayonesa
# agregar jamon
# cerrar pan
# listo!
