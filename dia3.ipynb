# %% [markdown]
# ## Challenge 1 🤺 - 10m
#
# Crear una función que imprima la variable palabra.

# %%
def imprimir_palabra(palabra):
    palabra = "hola"
    print(palabra)
imprimir_palabra("palabra")
# Out:
# hola

# %%
def suma_numeros(numero1, numero2):
    suma = numero1 + numero2
    print(suma)
suma_numeros(1, 2)
# Out:
# 3

# %% [markdown]
# ## Challenge 2 🤺 - 20 min
# Crear una función que reciba dos letras (parámetros) y que verifique si son iguales:
#
# 1. Si son iguales, imprimir "Las letras son iguales".
#
# 2. De lo contrario, imprimir "Las letras son diferentes".

# %%
def imprimir_letras_iguales(a,b,):
    if a != b:
     print('iguales')
    #si son iguales a y b 
    #se imprime letras iguales
    else :
     print('distintos')
    #de lo contrario
    #imprimimos letras son diferentes

# %%
def sumatoria(numero1 + numero2):
    sumar = (numero1),(numero2):
    return sumar
sumatoria(1, 2)
# Out:
#   Cell In[54], line 1
#     def sumatoria(numero1 + numero2):
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Challenge 3 🤺 - 20m
#
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne `True` si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne `False`.
#
# Pista: `cantidad de letras de una palabra en python`

# %%
def comparar_longitud(palabra,(int(6)):
    if len (palabra) == numero
    return
    palabra = "carmen"
    longitud = len(palabra)
    return longitud == 6
# Out:
#   Cell In[37], line 1
#     def comparar_longitud(palabra,(int(6))):
#                                   ^
# SyntaxError: invalid syntax

# %%
palabra_a_encontrar = input("ingresar una palabra")
print(palabra_a_encontrar)
palabra_ingresada = input("ingrese una palabra")
print(palabra_ingresada)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 palabra_a_encontrar = input("ingresar una palabra")
#       2 print(palabra_a_encontrar)
#       3 palabra_ingresada = input("ingrese una palabra")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
# ...

# %% [markdown]
# ## Challenge 5 🤺 - 25m
#
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con `list()`. Agregar esa lista de caracteres a una lista llamada `palabras_ingresadas`. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista `palabras_ingresadas`.
#
#
# Ejemplo del resultado esperado:
#
# ```[['c', 'i', 'e', 'l', 'o']]``` # Al ingresar la primera palabra
#
# ```[['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]``` # Al ingresar la segunda palabra
#
# ```[['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]``` # Al ingresar la tercera palabra

# %%
#iniciar la lista vacia para almacenar las listas de caracteres
palabras_ingresadas = []
#repetir el proceso 3 veces
for i in range(3):
    #pedir al usuario que ingrese una palabra
    palabra = input("Ingrese una palabra: ")
    #convertir la palabra en una lista de caracteres
    lista_de_caracteres = list(palabra)
    #agregar la lista de caracteres a palabras_ingresadas
    palabras_ingresadas.append(lista_de_caracteres)
    #imprimir la lista de palabras ingresadas
    print("Lista palabras ingresadas:", palabras_ingresadas)
# Out:
# Lista palabras ingresadas: [['C', 'a', 'r', 'm', 'e', 'n']]
# Lista palabras ingresadas: [['C', 'a', 'r', 'm', 'e', 'n'], ['L', 'i', 'l', 'i', 'a', 'n', 'a']]
# Lista palabras ingresadas: [['C', 'a', 'r', 'm', 'e', 'n'], ['L', 'i', 'l', 'i', 'a', 'n', 'a'], ['Q', 'u', 'i', 'n', 'o', 'n', 'e', 'z']]

# %% [markdown]
# ## Challenge 6 🤺 - 25m
#
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ```
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
# ```

# %%
#definir una lista
def imprimir_grilla(grilla):
    for sublista in grilla:
        print(sublista)

# lista de ejemplo[['h','o','l','i','s'],['h','e','l','l''o',]]
# llamar a la funcion imprimir lista 
lista = [['h','o','l','i','s'],['h','e','l','l','o',]]
imprimir_grilla(lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']

# %%
intentos = 3

while intentos > 0:
    print(f'te quedan (intentos) intentos')
    palabra = input('ingrese palabra')
    intentos = intentos - 1 

print('te quedaste sin intentos')

# %%
# definir la palabra a encontrar, intentos, cantidad de letras
palabra_a_encontrar = "virus"
cantidad_de_letras = 5
intentos = 6

# comparar las palabras( posicion correcta, si existe o no existe en la palabra)
def verificar_palabra_ingresada(palabra_a_encontrar, palabra_ingresada):

# definir una lista y agregar las letras verificadas
 resultado = [] 

 for posicion in range(cantidad_de_letras):
    las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]

    la_letra_existe = palabra_ingresada[posicion] in palabra_a_encontrar

    if las_letras_son_iguales:
      # agregar las letras entre corchetes
     resultado.append('[' +palabra_ingresada[posicion]+']')
    elif la_letra_existe:
       resultado.append('('+palabra_ingresada[posicion]+')')
    else: 
       resultado.append(palabra_ingresada[posicion])

 return resultado

# hacer la grilla
def imprimir_grilla(grilla):
    cantidad_de_filas = len(grilla)

    for fila in range(cantidad_de_filas):
        print(grilla[fila])

grilla = []

# bienvenida al wordle
print("bienvenido a Wordle")

# restar cantidad de intetos
while intentos > 0:
    print(f"te quedan {intentos}")
    palabra_ingresada = input("Ingrese la Palabra")
    

    if len(palabra_ingresada) != cantidad_de_letras:
        print(f"ingrese una palabra con {cantidad_de_letras} letras")
        continue 
    else:

# verificamos las palabras
     linea_verificada = verificar_palabra_ingresada(palabra_a_encontrar, palabra_ingresada)
    grilla.append(linea_verificada)

    intentos = intentos - 1
    imprimir_grilla(grilla)
    if palabra_ingresada == palabra_a_encontrar:
        print("GANASTEEE")
        break
# Out:
# bienvenido a Wordle
# te quedan 6
# ['[v]', '[i]', '[r]', '[u]', '[s]']
# GANASTEEE
